# %% [markdown]
# 1.- Crea un vector amb els números del 1 al 10. Mostra la seva longitud i el seu valor mitjà.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 2.- Crea un vector amb els valors: 'R', 'és', 'molt', 'divertit'. Mostra només la segona i la quarta paraula.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 3.- Crea dos vectors: a = c(2, 4, 6) i b = c(1, 3, 5). Suma’ls element a element.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 4.- Crea una matriu de 3 files i 3 columnes amb els nombres del 1 al 9, omplint-la per files. Mostra la segona fila.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 5.- Canvia el valor de la posició [3,2] de la matriu anterior per 99.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 6.- Crea un vector amb 10 números aleatoris entre 1 i 100. Mostra només els valors superiors a 50.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 7.- Crea una matriu de 4 files i 5 columnes amb els números del 1 al 20, omplint-la per files.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 8.- Crea una matriu 5x5 amb valors del 1 al 25. Calcula la mitjana de cada fila i cada columna.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 9.- Crea un factor amb els valors 'baix', 'mig', 'alt' repetits (Esbrina si hi ha una funció que et generi a partir d'un vector n valors repetits). Crea una matriu amb valors del 1 al 12 i combina-ho tot en un data.frame.
#
# Utilitza:
# data.frame(nivell, valors) on nivell seria el factor i valors la matriu.

# %%
# Escriu el teu codi aquí

# %% [markdown]
# 10.- Crea dues matrius compatibles, el número de columnes d'A i el número de files de B ha de ser igual, no poden ser matrius quadrades i calcula el producte matriu A %*% B.

# %%
# Escriu el teu codi aquí
